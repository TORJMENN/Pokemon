# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("pokemon.csv")

# %%
df.head()
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# 1      80  ...  Green       True    0.875     Monster        Grass
# 2     100  ...  Green       True    0.875     Monster        Grass
# 3      50  ...    Red       True    0.875     Monster       Dragon
# 4      65  ...    Red       True    0.875     Monster       Dragon
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# ...

# %%
df.shape
# Out:
# (721, 23)

# %%
df.drop(df.iloc[:, 13:23],inplace=True, axis=1)

# %%
df
# Out:
#      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying    680  126     131       95     131
# 717     718     Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719     Diancie     Rock   Fairy    600   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721   Volcanion     Fire   Water    600   80     110      120     130
#
# ...

# %%
df.rename(columns={'isLegendary': 'Legendary', 'Type_1': 'Type 1','Type_2': 'Type 2'}, inplace=True)

# %%
df.head()
# Out:
#    Number        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      80     60           1      False
# 2     100     80           1      False
# 3      50     65           1      False
# 4      65     80           1      False

# %%
df.describe()
# Out:
#           Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  721.00000  721.000000  721.000000  721.000000  721.000000  721.000000
# mean   361.00000  417.945908   68.380028   75.013870   70.808599   68.737864
# std    208.27906  109.663671   25.848272   28.984475   29.296558   28.788005
# min      1.00000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    181.00000  320.000000   50.000000   53.000000   50.000000   45.000000
# 50%    361.00000  424.000000   65.000000   74.000000   65.000000   65.000000
# 75%    541.00000  499.000000   80.000000   95.000000   85.000000   90.000000
# max    721.00000  720.000000  255.000000  165.000000  230.000000  154.000000
#
#            Sp_Def       Speed  Generation
# count  721.000000  721.000000  721.000000
# mean    69.291262   65.714286    3.323162
# std     27.015860   27.277920    1.669873
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# ...

# %% [markdown]
# #### Distribution of Pokemon Types:

# %%
df['Type 1'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='tab20c', figsize=(10, 8))
# Out:
# <AxesSubplot:ylabel='Type 1'>

# %% [markdown]
# #### Distribution of Pokemon Totals:

# %%
df['Total'].plot(kind='hist', figsize=(10, 8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Total'].plot(kind='box', vert=False, figsize=(10, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Distribution of Pokemon Totals:

# %%
df['Legendary'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='Set3', figsize=(10, 8))
# Out:
# <AxesSubplot:ylabel='Legendary'>

# %% [markdown]
# # Filtering

# %% [markdown]
# #### How many Pokemons exist with an Attack value greater than 150?

# %%
sns.boxplot(data=df, x='Attack')
# Out:
# <AxesSubplot:xlabel='Attack'>

# %%
df.loc[df['Attack']>150]
# Out:
#      Number       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp_Atk  \
# 288     289    Slaking  Normal    NaN    670  150     160      100      95
# 408     409  Rampardos    Rock    NaN    495   97     165       60      65
# 485     486  Regigigas  Normal    NaN    670  110     160      110      80
#
#      Sp_Def  Speed  Generation  Legendary
# 288      65    100           3      False
# 408      50     58           4      False
# 485     110    100           4       True

# %% [markdown]
# #### all pokemons with a Speed of `10` or less

# %%
sns.boxplot(data=df, x='Speed')
# Out:
# <AxesSubplot:xlabel='Speed'>

# %%
slow_pokemons_df = df[df['Speed']<=10]
slow_pokemons_df
# Out:
#      Number       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp_Atk  \
# 212     213    Shuckle     Bug   Rock    505   20      10      230      10
# 327     328   Trapinch  Ground    NaN    290   45     100       45      45
# 437     438     Bonsly    Rock    NaN    290   50      80       95      10
# 445     446   Munchlax  Normal    NaN    390  135      85       40      40
# 596     597  Ferroseed   Grass  Steel    305   44      50       91      24
#
#      Sp_Def  Speed  Generation  Legendary
# 212     230      5           2      False
# 327      45     10           3      False
# 437      45     10           4      False
# 445      85      5           4      False
# 596      86     10           5      False

# %% [markdown]
# ####  How many Pokemons have a `Sp. Def` value of 25 or less?

# %%
df.loc[df['Sp_Def']<=25].shape
# Out:
# (17, 13)

# %% [markdown]
# #### all the Legendary pokemons

# %%
legendary_df = df.loc[df['Legendary']==True]
legendary_df.head()
# Out:
#      Number      Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp_Atk  \
# 143     144  Articuno       Ice  Flying    580   90      85      100      95
# 144     145    Zapdos  Electric  Flying    580   90      90       85     125
# 145     146   Moltres      Fire  Flying    580   90     100       90     125
# 149     150    Mewtwo   Psychic     NaN    680  106     110       90     154
# 242     243    Raikou  Electric     NaN    580   90      85       75     115
#
#      Sp_Def  Speed  Generation  Legendary
# 143     125     85           1       True
# 144      90    100           1       True
# 145      85     90           1       True
# 149      90    130           1       True
# 242     100    115           2       True

# %% [markdown]
# #### Who is the pokemon that is clearly an outlier in terms of Attack / Defense ?

# %%
ax = sns.scatterplot(data=df, x="Defense", y="Attack")
ax.annotate(
    "Who's this guy?", xy=(228, 10), xytext=(150, 10), color='red',
    arrowprops=dict(arrowstyle="->", color='red')
)
# Out:
# Text(150, 10, "Who's this guy?")

# %%
#df.loc[(df['Defense']>200)&(df['Attack']<20)]
df.query("Defense > 200")
# Out:
#      Number     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp_Atk  \
# 212     213  Shuckle    Bug   Rock    505  20      10      230      10
#
#      Sp_Def  Speed  Generation  Legendary
# 212     230      5           2      False

# %% [markdown]
# # Selection

# %% [markdown]
# #### How many Fire-Flying Pokemons are there? (5)

# %%
df.loc[(df['Type 1']=='Fire')&(df['Type 2']=='Flying'),'Type 2'].shape
# Out:
# (5,)

# %% [markdown]
# #### How many 'Poison' pokemons are across both types? (59)

# %%
df.loc[(df['Type 1']=='Poison')|(df['Type 2']=='Poison'),].shape
# Out:
# (59, 13)

# %% [markdown]
# #### What pokemon of Type 1 Ice has the strongest defense? (Avalugg)

# %%
df.loc[df['Type 1'] == 'Ice'].sort_values(by='Defense', ascending=False).head()
# Out:
#      Number      Name Type 1  Type 2  Total   HP  Attack  Defense  Sp_Atk  \
# 712     713   Avalugg    Ice     NaN    514   95     117      184      44
# 470     471   Glaceon    Ice     NaN    525   65      60      110     130
# 143     144  Articuno    Ice  Flying    580   90      85      100      95
# 377     378    Regice    Ice     NaN    580   80      50      100     100
# 364     365   Walrein    Ice   Water    530  110      80       90      95
#
#      Sp_Def  Speed  Generation  Legendary
# 712      46     28           6      False
# 470      95     65           4      False
# 143     125     85           1       True
# 377     200     50           3       True
# 364      90     65           3      False

# %% [markdown]
# #### What's the most common type of Legendary Pokemons? (Psychic)

# %%
df.loc[df['Legendary'] == True,'Type 1'].value_counts().head(1)
# Out:
# Psychic    8
# Name: Type 1, dtype: int64

# %% [markdown]
# #### the most powerful Dragon from the last two generations

# %%
df.loc[(df['Generation']>=5)&(df['Type 1']=='Water')].sort_values(by='Total',ascending=False).head(1)
# Out:
#      Number    Name Type 1    Type 2  Total  HP  Attack  Defense  Sp_Atk  \
# 646     647  Keldeo  Water  Fighting    580  91      72       90     129
#
#      Sp_Def  Speed  Generation  Legendary
# 646      90    108           5      False

# %% [markdown]
# #### Select most powerful Fire-type pokemons

# %%
powerful_fire_df = df.loc[(df['Attack']>100)&(df['Type 1']=='Fire')]
powerful_fire_df
# Out:
#      Number        Name Type 1    Type 2  Total   HP  Attack  Defense  Sp_Atk  \
# 58       59    Arcanine   Fire       NaN    555   90     110       80     100
# 135     136     Flareon   Fire       NaN    525   65     130       60      95
# 243     244       Entei   Fire       NaN    580  115     115       85      90
# 249     250       Ho-Oh   Fire    Flying    680  106     130       90     110
# 256     257    Blaziken   Fire  Fighting    530   80     120       70     110
# 391     392   Infernape   Fire  Fighting    534   76     104       71     104
# 499     500      Emboar   Fire  Fighting    528  110     123       65     100
# 554     555  Darmanitan   Fire       NaN    480  105     140       55      30
# 720     721   Volcanion   Fire     Water    600   80     110      120     130
#
#      Sp_Def  Speed  Generation  Legendary
# 58       80     95           1      False
# 135     110     65           1      False
# 243      75    100           2       True
# ...

# %% [markdown]
# #### Select all Water-type, Flying-type pokemons

# %%
water_flying_df = df.loc[(df['Type 1']=='Water')&(df['Type 2']=='Flying')]
water_flying_df
# Out:
#      Number      Name Type 1  Type 2  Total  HP  Attack  Defense  Sp_Atk  \
# 129     130  Gyarados  Water  Flying    540  95     125       79      60
# 225     226   Mantine  Water  Flying    465  65      40       70      80
# 277     278   Wingull  Water  Flying    270  40      30       30      55
# 278     279  Pelipper  Water  Flying    430  60      50      100      85
# 457     458   Mantyke  Water  Flying    345  45      20       50      60
# 579     580  Ducklett  Water  Flying    305  62      44       50      44
# 580     581    Swanna  Water  Flying    473  75      87       63      87
#
#      Sp_Def  Speed  Generation  Legendary
# 129     100     81           1      False
# 225     140     70           2      False
# 277      30     85           3      False
# 278      70     65           3      False
# 457     120     50           4      False
# 579      50     55           5      False
# 580      63     98           5      False

# %% [markdown]
# #### Select specific columns of Legendary pokemons of type Fire

# %%
legendary_fire_df = df.loc[(df['Type 1']=='Fire')&(df['Legendary']==True),['Name','Attack','Generation']]
legendary_fire_df
# Out:
#           Name  Attack  Generation
# 145    Moltres     100           1
# 243      Entei     115           2
# 249      Ho-Oh     130           2
# 484    Heatran      90           4
# 720  Volcanion     110           6

# %% [markdown]
# #### Select Slow and Fast pokemons

# %%
ax = df['Speed'].plot(kind='hist', figsize=(10, 5), bins=100)
ax.axvline(df['Speed'].quantile(.05), color='red')
ax.axvline(df['Speed'].quantile(.95), color='red')

# %%
slow_fast_df = df.loc[
    (df['Speed'] < df['Speed'].quantile(.05)) |
    (df['Speed'] > df['Speed'].quantile(.95))
]
slow_fast_df
# Out:
#      Number        Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 38       39  Jigglypuff    Normal   Fairy    270  115      45       20
# 50       51     Dugtrio    Ground     NaN    405   35      80       50
# 52       53     Persian    Normal     NaN    440   65      70       60
# 64       65    Alakazam   Psychic     NaN    500   55      50       45
# 73       74     Geodude      Rock  Ground    300   40      80      100
# ..      ...         ...       ...     ...    ...  ...     ...      ...
# 657     658    Greninja     Water    Dark    530   72      95       67
# 662     663  Talonflame      Fire  Flying    499   78      81       71
# 681     682    Spritzee     Fairy     NaN    341   78      52       60
# 700     701    Hawlucha  Fighting  Flying    500   78      92       75
# 714     715     Noivern    Flying  Dragon    535   85      70       80
#
#      Sp_Atk  Sp_Def  Speed  Generation  Legendary
# 38       45      25     20           1      False
# ...

# %% [markdown]
# #### the Ultra Powerful Legendary Pokemon (Rayquaza)

# %%
fig, ax = plt.subplots(figsize=(14, 7))
sns.scatterplot(data=df, x="Defense", y="Attack", hue='Legendary', ax=ax)
ax.annotate(
    "Who's this guy?", xy=(140, 150), xytext=(160, 150), color='red',
    arrowprops=dict(arrowstyle="->", color='red')
)
# Out:
# Text(160, 150, "Who's this guy?")

# %%
df.loc[df['Attack']==150].sort_values(by='Total',ascending=False).head(1)
# Out:
#      Number      Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp_Atk  \
# 383     384  Rayquaza  Dragon  Flying    680  105     150       90     150
#
#      Sp_Def  Speed  Generation  Legendary
# 383      90     95           3       True
